# %%
# %matplotlib inline

# %%
import pandas as pd
# Out:
# /Users/r-p1e/anaconda3/lib/python3.5/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
df = pd.read_csv("../input/Hypothesis_TA_VK_groups.csv", names=["title", "link", "size",3,4,5]).dropna(subset=["link"])

# %%
df.head()
# Out:
#                                             title  \
# 3                                 Таганский район
# 4              Йога-центр "АНАНТА" (м. Таганская)
# 5     Репетитор Английского в Москве м. Таганская
# 6              Парк Культуры и Отдыха "Таганский"
# 7  Студия танца ALPHA DANCE. Хастл. м. Таганская.
#
#                             link  size    3    4    5
# 3  https://vk.com/public74953385  1543  NaN  NaN  NaN
# 4     https://vk.com/club8772336  1984  NaN  NaN  NaN
# 5    https://vk.com/club14567932  1056  NaN  NaN  NaN
# 6   https://vk.com/parktaganskiy   358  NaN  NaN  NaN
# 7   https://vk.com/alphadance_ru  7661  NaN  NaN  NaN

# %%
import requests

def getById(gid, fields=None, access_token=None):
    """
    Get info about group by gid or it's name. You can extract
    group name from it's link.
    """
    extended_fields = fields or {}
    extended_fields.update({"group_id": gid})
    return vkapirequest("groups.getById",
                        parameters=extended_fields,
                        access_token=access_token)


def getMembers(gid, fields=None, access_token=None):
    """
    Here gid must be group id (number). That my opinion.
    You can get it with getById function.
    """
    extended_fields = fields or {}
    extended_fields.update({"group_id": gid})
    return vkapirequest("groups.getMembers",
                        parameters=extended_fields,
                        access_token=access_token)


# ---- Utils -----
def vkapirequest(method, parameters=None, access_token=None):
    def getParamsOrNothing(params):
        if params is None:
            return ""
        else:
            return "?{}".format('&'.join(["{}={}".format(k, v)
                                          for k, v in params.items()]))

    def getATorNothing(at):
        if at is None:
            return ""
        else:
            return "&access_token={}".format(at)

    base_url = "https://api.vk.com/method/"
    url = "{}{}{}{}".format(base_url, method, getParamsOrNothing(parameters),
                            getATorNothing(access_token))
    print(url)
    return requests.get(url).json()

# %%
getById("public74953385")
# Out:
# https://api.vk.com/method/groups.getById?group_id=public74953385
# {'error': {'error_code': 100,
#   'error_msg': 'One of the parameters specified was missing or invalid: group_ids is undefined',
#   'request_params': [{'key': 'oauth', 'value': '1'},
#    {'key': 'method', 'value': 'groups.getById'},
#    {'key': 'group_id', 'value': 'public74953385'}]}}

# %%
getById("club8772336")
# Out:
# https://api.vk.com/method/groups.getById?group_id=club8772336
# {'response': [{'gid': 8772336,
#    'is_closed': 0,
#    'name': 'Йога-центр "АНАНТА"  (м. Таганская)',
#    'photo': 'http://cs4307.vk.me/g8772336/e_e19290cb.jpg',
#    'photo_big': 'http://cs4307.vk.me/g8772336/d_56fc2192.jpg',
#    'photo_medium': 'http://cs4307.vk.me/g8772336/d_56fc2192.jpg',
#    'screen_name': 'club8772336',
#    'type': 'group'}]}

# %%
getMembers(8772336)
# Out:
# https://api.vk.com/method/groups.getMembers?group_id=8772336
# {'response': {'count': 1984,
#   'users': [2156,
#    11419,
#    31740,
#    52698,
#    57317,
#    86276,
#    101228,
#    108372,
#    113786,
#    123393,
#    124239,
#    133763,
#    138660,
#    168766,
#    173574,
#    181521,
#    182385,
#    216448,
#    223255,
#    235921,
#    237987,
#    240929,
#    244574,
#    246611,
#    258072,
#    259233,
#    297314,
#    305546,
#    307380,
#    338799,
#    351565,
#    371881,
#    381060,
#    387785,
#    401606,
#    463758,
#    471430,
#    475968,
